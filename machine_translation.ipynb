# %%
import pandas as pd

# %%
ks = pd.read_csv('data/kidsspelling.csv')
ks = ks.drop(['Code', 'Semester', 'Unnamed: 4'], axis=1)
ks = ks.dropna()
ks["Target"] = ks.Target.apply(lambda x: x.strip())
ks[0:5]
# Out:
#       Target  Spelling
# 0   favorite    favtit
# 1      throw      thow
# 2      catch      cach
# 3  touchdown  tuchdone
# 4      dance      dans

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# %%
def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# %%
# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
    # integer encode sequences
    X = tokenizer.texts_to_sequences(lines)
    print(len(X), X[0])
    # pad sequences with 0 values
    X = pad_sequences(X, maxlen=length, padding='post')
    return X

# %%
# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# %%
spelling_tokens = [[letter for letter in word] for word in ks['Spelling']]
target_tokens = [[letter for letter in word] for word in ks['Target']]

spelling_train = spelling_tokens[:900]
target_train = target_tokens[:900]

spelling_test = spelling_tokens[900:]
target_test = target_tokens[900:]
len(target_test)
# Out:
# 458

# %%
spelling_tokenizer = create_tokenizer(spelling_tokens)
target_tokenizer = create_tokenizer(target_tokens)

# %%
spelling_size = len(spelling_tokenizer.word_index)+1
target_size = len(target_tokenizer.word_index)+1
target_size
# Out:
# 32

# %%
spelling_max = max(len(token) for token in spelling_tokens)
target_max =  max(len(token) for token in target_tokens)
target_max
# Out:
# 17

# %%
# prepare training data
trainX = encode_sequences(spelling_tokenizer, spelling_max, spelling_train)
trainY = encode_sequences(target_tokenizer, target_max, target_train)
trainY = encode_output(trainY, target_size)
# prepare validation data
testX = encode_sequences(spelling_tokenizer, spelling_max, spelling_test)
testY = encode_sequences(target_tokenizer, target_max, target_test)
testY = encode_output(testY, target_size)
# Out:
# 900 [17, 4, 22, 3, 5, 3]
# 900 [19, 4, 22, 6, 7, 3, 2, 1]
# 458 [9, 4, 8, 12, 5, 12]
# 458 [9, 4, 8, 12, 1, 12]

# %%
# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# %%
# define model
model = define_model(spelling_size, target_size, spelling_max, target_max, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
#plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 14, 256)           7680
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 17, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 17, 256)           525312
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 17, 32)            8224
# =================================================================
# Total params: 1,066,528
# Trainable params: 1,066,528
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=30, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# Train on 900 samples, validate on 458 samples
# Epoch 1/30
#  - 19s - loss: 2.4612 - val_loss: 1.5337
#
# Epoch 00001: val_loss improved from inf to 1.53368, saving model to model.h5
# Epoch 2/30
#  - 9s - loss: 1.3558 - val_loss: 1.2983
#
# Epoch 00002: val_loss improved from 1.53368 to 1.29831, saving model to model.h5
# Epoch 3/30
#  - 8s - loss: 1.2445 - val_loss: 1.3173
#
# Epoch 00003: val_loss did not improve from 1.29831
# Epoch 4/30
#  - 8s - loss: 1.2134 - val_loss: 1.2290
#
# Epoch 00004: val_loss improved from 1.29831 to 1.22897, saving model to model.h5
# Epoch 5/30
#  - 8s - loss: 1.1869 - val_loss: 1.2239
#
# Epoch 00005: val_loss improved from 1.22897 to 1.22388, saving model to model.h5
# Epoch 6/30
#  - 8s - loss: 1.1618 - val_loss: 1.1942
#
# Epoch 00006: val_loss improved from 1.22388 to 1.19425, saving model to model.h5
# Epoch 7/30
#  - 8s - loss: 1.1300 - val_loss: 1.1683
#
# Epoch 00007: val_loss improved from 1.19425 to 1.16831, saving model to model.h5
# Epoch 8/30
#  - 9s - loss: 1.1034 - val_loss: 1.1234
#
# Epoch 00008: val_loss improved from 1.16831 to 1.12343, saving model to model.h5
# Epoch 9/30
#  - 8s - loss: 1.0784 - val_loss: 1.1046
#
# Epoch 00009: val_loss improved from 1.12343 to 1.10459, saving model to model.h5
# Epoch 10/30
#  - 8s - loss: 1.0608 - val_loss: 1.1001
#
# Epoch 00010: val_loss improved from 1.10459 to 1.10011, saving model to model.h5
# Epoch 11/30
#  - 8s - loss: 1.0477 - val_loss: 1.0912
#
# Epoch 00011: val_loss improved from 1.10011 to 1.09120, saving model to model.h5
# Epoch 12/30
#  - 8s - loss: 1.0415 - val_loss: 1.1061
#
# Epoch 00012: val_loss did not improve from 1.09120
# Epoch 13/30
#  - 8s - loss: 1.0636 - val_loss: 1.0925
#
# Epoch 00013: val_loss did not improve from 1.09120
# Epoch 14/30
#  - 10s - loss: 1.0358 - val_loss: 1.0827
#
# Epoch 00014: val_loss improved from 1.09120 to 1.08272, saving model to model.h5
# Epoch 15/30
#  - 10s - loss: 1.0279 - val_loss: 1.0789
#
# Epoch 00015: val_loss improved from 1.08272 to 1.07886, saving model to model.h5
# Epoch 16/30
#  - 10s - loss: 1.0231 - val_loss: 1.0711
#
# Epoch 00016: val_loss improved from 1.07886 to 1.07114, saving model to model.h5
# Epoch 17/30
#  - 8s - loss: 1.0360 - val_loss: 1.0658
#
# Epoch 00017: val_loss improved from 1.07114 to 1.06581, saving model to model.h5
# Epoch 18/30
#  - 8s - loss: 1.0149 - val_loss: 1.0461
#
# Epoch 00018: val_loss improved from 1.06581 to 1.04612, saving model to model.h5
# Epoch 19/30
#  - 8s - loss: 0.9989 - val_loss: 1.0348
#
# Epoch 00019: val_loss improved from 1.04612 to 1.03477, saving model to model.h5
# Epoch 20/30
#  - 8s - loss: 0.9768 - val_loss: 1.0252
#
# Epoch 00020: val_loss improved from 1.03477 to 1.02524, saving model to model.h5
# Epoch 21/30
#  - 8s - loss: 0.9637 - val_loss: 1.0097
#
# Epoch 00021: val_loss improved from 1.02524 to 1.00967, saving model to model.h5
# Epoch 22/30
#  - 8s - loss: 0.9410 - val_loss: 0.9941
#
# Epoch 00022: val_loss improved from 1.00967 to 0.99407, saving model to model.h5
# Epoch 23/30
#  - 8s - loss: 0.9302 - val_loss: 1.0068
#
# Epoch 00023: val_loss did not improve from 0.99407
# Epoch 24/30
#  - 8s - loss: 0.9193 - val_loss: 0.9724
#
# Epoch 00024: val_loss improved from 0.99407 to 0.97238, saving model to model.h5
# Epoch 25/30
#  - 8s - loss: 0.8984 - val_loss: 0.9597
#
# Epoch 00025: val_loss improved from 0.97238 to 0.95966, saving model to model.h5
# Epoch 26/30
#  - 9s - loss: 0.8769 - val_loss: 0.9503
#
# Epoch 00026: val_loss improved from 0.95966 to 0.95033, saving model to model.h5
# Epoch 27/30
#  - 8s - loss: 0.8578 - val_loss: 0.9446
#
# Epoch 00027: val_loss improved from 0.95033 to 0.94456, saving model to model.h5
# Epoch 28/30
#  - 12s - loss: 0.8528 - val_loss: 0.9498
#
# Epoch 00028: val_loss did not improve from 0.94456
# Epoch 29/30
#  - 10s - loss: 0.8321 - val_loss: 0.9213
#
# Epoch 00029: val_loss improved from 0.94456 to 0.92134, saving model to model.h5
# Epoch 30/30
#  - 9s - loss: 0.8128 - val_loss: 0.9102
#
# Epoch 00030: val_loss improved from 0.92134 to 0.91021, saving model to model.h5

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model

# %%
model = load_model('model.h5')

# %%
# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# %%
def evaluate_model(model, tokenizer, sources, spelling_train, target_train):
    correct = []
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, target_tokenizer, source).replace(" ", "")
        raw_target, raw_src = ''.join(target_train[i]), ''.join(spelling_train[i])
        print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
        correct.append(raw_target == translation)
    print(str(sum(correct))+ " / " +str(len(correct)))
   
# for s, t in zip(spelling_tokens, target_tokens):
  #  translation = predict_sequence(model, eng_tokenizer, source)

# %%
evaluate_model(model, target_tokenizer, trainX, spelling_train, target_train)
# Out:
# src=[favtit], target=[favorite], predicted=[tttttt]
# src=[thow], target=[throw], predicted=[thhh]
# src=[cach], target=[catch], predicted=[sooo]
# src=[tuchdone], target=[touchdown], predicted=[ccooohh]
# src=[dans], target=[dance], predicted=[siies]
# src=[villajg], target=[villager], predicted=[llllle]
# src=[pots], target=[puts], predicted=[sosss]
# src=[cadig], target=[cabbage], predicted=[saaee]
# src=[carit], target=[carrot], predicted=[tttte]
# src=[smels], target=[smells], predicted=[semmss]
# src=[ston], target=[stone], predicted=[soit]
# src=[soop], target=[soup], predicted=[soooe]
# src=[magick], target=[magic], predicted=[saiii]
# src=[Jonsun], target=[Johnson], predicted=[fiiiin]
# src=[fol], target=[full], predicted=[wlll]
# src=[korts], target=[court], predicted=[sotss]
# src=[haf], target=[half], predicted=[whe]
# src=[korts], target=[court], predicted=[sotss]
# src=[Lackrs], target=[Lakers], predicted=[cllcees]
# src=[scoot], target=[scooped], predicted=[soooo]
# src=[gast], target=[gasped], predicted=[ssss]
# src=[chard], target=[charged], predicted=[tarre]
# src=[crassy], target=[crazy], predicted=[seaee]
# src=[xspladed], target=[exploded], predicted=[seiiidd]
# src=[wus], target=[was], predicted=[ssss]
# src=[wus], target=[was], predicted=[ssss]
# src=[frst], target=[first], predicted=[sttt]
# src=[tedye], target=[teddy], predicted=[saeyy]
# src=[tedye], target=[teddy], predicted=[saeyy]
# src=[picher], target=[picture], predicted=[trttre]
# src=[whant], target=[when], predicted=[hhnn]
# src=[piecher], target=[picture], predicted=[ccctree]
# src=[probly], target=[probably], predicted=[bollll]
# src=[tedyear], target=[teddy], predicted=[baaayy]
# src=[og], target=[go], predicted=[woo]
# src=[frst], target=[first], predicted=[sttt]
# src=[tedeeber], target=[teddy bear], predicted=[brrrrrre]
# src=[librareay], target=[library], predicted=[ceacaryy]
# src=[gound], target=[ground], predicted=[foooe]
# src=[thay], target=[they], predicted=[they]
# src=[egs], target=[eggs], predicted=[ssss]
# src=[mufin], target=[muffin], predicted=[fiinn]
# src=[becuse], target=[because], predicted=[scccss]
# src=[tasts], target=[tastes], predicted=[sssss]
# src=[choclete], target=[chocolate], predicted=[cooooo]
# src=[cooice], target=[cookies], predicted=[cooooe]
# src=[delecious], target=[delicious], predicted=[cllccooss]
# src=[infinit], target=[infinite], predicted=[fiiinnn]
# src=[coockie], target=[cookie], predicted=[cooooo]
# src=[marvills], target=[marvelous], predicted=[lllllee]
# src=[punat butter], target=[peanut butter], predicted=[cttttttttt]
# src=[cockotate], target=[chocolate], predicted=[cooooot]
# src=[mowth], target=[mouth], predicted=[hooh]
# src=[aellien], target=[alien], predicted=[llllnn]
# src=[shautd], target=[shouted], predicted=[stttee]
# src=[spacecrafe], target=[spacecraft], predicted=[ccccccaaa]
# src=[aellien], target=[alien], predicted=[llllnn]
# src=[fote], target=[fought], predicted=[toot]
# src=[sot], target=[shot], predicted=[soot]
# src=[recshed], target=[reached], predicted=[saaaee]
# src=[redea], target=[ready], predicted=[saed]
# src=[camoflage], target=[camouflage], predicted=[clooooo]
# src=[wepin], target=[weapon], predicted=[finnn]
# src=[mushean], target=[machine], predicted=[saiiii]
# src=[amoe], target=[ammo], predicted=[saml]
# src=[portections], target=[protections], predicted=[ceecttttt]
# src=[plases], target=[places], predicted=[seessss]
# src=[ovoyd], target=[avoid], predicted=[wooll]
# src=[geting], target=[getting], predicted=[tiiing]
# src=[utack], target=[attack], predicted=[toook]
# src=[ather], target=[other], predicted=[thhhe]
# src=[taset], target=[taste], predicted=[sttte]
# src=[solty], target=[salty], predicted=[coool]
# src=[tastes], target=[tasts], predicted=[ssssss]
# src=[weat], target=[wheat], predicted=[whee]
# src=[bu], target=[bun], predicted=[soe]
# src=[meet], target=[meat], predicted=[saee]
# src=[soseg], target=[sausage], predicted=[sssss]
# src=[dilishes], target=[delicious], predicted=[sliiiiiss]
# src=[taset], target=[taste], predicted=[sttte]
# src=[dilishes], target=[delicious], predicted=[sliiiiiss]
# src=[oniens], target=[onions], predicted=[fiiinn]
# src=[sos], target=[sauce], predicted=[ssss]
# src=[taset], target=[taste], predicted=[sttte]
# src=[dilishes], target=[delicious], predicted=[sliiiiiss]
# src=[sos], target=[sauce], predicted=[ssss]
# src=[comperyhention], target=[comprehension], predicted=[ceeciiiin]
# src=[revisen], target=[revision], predicted=[siiiiii]
# src=[dilishes], target=[delicious], predicted=[sliiiiiss]
# src=[hiting], target=[hitting], predicted=[tiinng]
# src=[makeing], target=[making], predicted=[aiinnn]
# src=[dribiling], target=[dribbling], predicted=[fliiiiin]
# src=[gos], target=[goes], predicted=[soss]
# src=[butery], target=[buttery], predicted=[ttttre]
# src=[taset], target=[taste], predicted=[sttte]
# src=[dilishes], target=[delicious], predicted=[sliiiiiss]
# src=[hapened], target=[happened], predicted=[faaeeee]
# src=[sed], target=[said], predicted=[saed]
# src=[sum thing], target=[something], predicted=[stttiiin]
# src=[wildernis], target=[wilderness], predicted=[flliieees]
# src=[gose], target=[goes], predicted=[soss]
# src=[pitchers], target=[pictures], predicted=[stttrre]
# src=[realy], target=[really], predicted=[aallyy]
# src=[whants], target=[wants], predicted=[tiitt]
# src=[hapened], target=[happened], predicted=[faaeeee]
# src=[sentenses], target=[sentences], predicted=[siiiisss]
# src=[realy], target=[really], predicted=[aallyy]
# src=[herd], target=[heard], predicted=[trre]
# src=[nois], target=[noise], predicted=[siiss]
# src=[nois], target=[noise], predicted=[siiss]
# src=[scard], target=[scared], predicted=[saaaee]
# src=[jest], target=[just], predicted=[ssss]
# src=[choise], target=[choice], predicted=[soouse]
# src=[grate], target=[great], predicted=[ttrte]
# src=[armer], target=[armor], predicted=[saaee]
# src=[brite], target=[bright], predicted=[trrte]
# src=[wons], target=[once], predicted=[woon]
# src=[rideing], target=[riding], predicted=[fiiinn]
# src=[whnt], target=[went], predicted=[thng]
# src=[thro], target=[through], predicted=[thhh]
# src=[opsticol], target=[obstacle], predicted=[scccooo]
# src=[cors], target=[course], predicted=[souss]
# src=[barls], target=[barrels], predicted=[saaeee]
# src=[wen], target=[when], predicted=[wnn]
# src=[cam], target=[came], predicted=[smm]
# src=[cot], target=[caught], predicted=[toot]
# src=[gat], target=[gate], predicted=[ttt]
# src=[monky], target=[monkey], predicted=[wolk]
# src=[skreming], target=[screaming], predicted=[siiiiii]
# src=[donats], target=[doughnuts], predicted=[foooes]
# src=[donuts], target=[doughnuts], predicted=[sooooss]
# src=[now], target=[new], predicted=[won]
# src=[mad], target=[made], predicted=[see]
# src=[know], target=[new], predicted=[won]
# src=[ware], target=[we're], predicted=[waee]
# src=[sam], target=[same], predicted=[sme]
# src=[wer], target=[were], predicted=[wee]
# src=[igsiting], target=[exciting], predicted=[siiiiin]
# src=[wors], target=[worse], predicted=[soee]
# src=[gust], target=[just], predicted=[ssss]
# src=[tuk], target=[took], predicted=[woo]
# src=[sed], target=[said], predicted=[saed]
# src=[kep], target=[kept], predicted=[wie]
# src=[leving], target=[leaving], predicted=[fiiinn]
# src=[sum thing], target=[something], predicted=[stttiiin]
# src=[know], target=[new], predicted=[won]
# src=[ther], target=[there], predicted=[thrr]
# src=[monky], target=[monkey], predicted=[wolk]
# src=[inchrodoost], target=[introduced], predicted=[cccctrrre]
# src=[wuod], target=[would], predicted=[wool]
# src=[sum], target=[some], predicted=[ssme]
# src=[anmls], target=[animals], predicted=[siiees]
# src=[cum], target=[come], predicted=[smme]
# src=[chran], target=[train], predicted=[thhhh]
# src=[everwone], target=[everyone], predicted=[aaalnee]
# src=[freat], target=[freaked], predicted=[trree]
# src=[tokeg], target=[talking], predicted=[woooe]
# src=[everwone], target=[everyone], predicted=[aaalnee]
# src=[sid], target=[said], predicted=[saed]
# src=[way], target=[why], predicted=[hy]
# src=[tokes], target=[talking], predicted=[sooue]
# src=[ove], target=[of], predicted=[wole]
# src=[weth], target=[with], predicted=[thhh]
# src=[sume], target=[some], predicted=[smmme]
# src=[wint], target=[went], predicted=[winn]
# src=[up stars], target=[upstairs], predicted=[ssccssss]
# src=[upstars], target=[upstairs], predicted=[ssstsss]
# src=[ave], target=[of], predicted=[wae]
# src=[lokrs], target=[lockers], predicted=[coooee]
# src=[blu], target=[blue], predicted=[woll]
# src=[chokolet], target=[chocolate], predicted=[coooole]
# src=[tast], target=[taste], predicted=[sttt]
# src=[becase], target=[because], predicted=[saccse]
# src=[ran ], target=[rain], predicted=[win]
# src=[stad], target=[stayed], predicted=[saaed]
# src=[insaen], target=[inside], predicted=[siiiin]
# src=[reses], target=[recess], predicted=[sssss]
# src=[stad], target=[stayed], predicted=[saaed]
# src=[agen], target=[again], predicted=[winn]
# src=[insid], target=[inside], predicted=[siiid]
# src=[wen], target=[when], predicted=[wnn]
# src=[raning], target=[raining], predicted=[iinnnn]
# src=[wen], target=[went], predicted=[wnn]
# src=[becas ], target=[because], predicted=[saccme]
# src=[frind], target=[friend], predicted=[fiinn]
# src=[hase], target=[house], predicted=[seee]
# src=[gona], target=[going to (gonna)], predicted=[woon]
# src=[winn], target=[when], predicted=[wnnnn]
# src=[littol], target=[little], predicted=[coool]
# src=[rid ], target=[ride], predicted=[seed]
# src=[frinds], target=[friends], predicted=[fiiies]
# src=[lian], target=[lion], predicted=[winn]
# src=[lian], target=[lion], predicted=[winn]
# src=[sid], target=[said], predicted=[saed]
# src=[lian], target=[lion], predicted=[winn]
# src=[lian], target=[lion], predicted=[winn]
# src=[prod], target=[proud], predicted=[foedd]
# src=[litol], target=[little], predicted=[wolll]
# src=[fist], target=[first], predicted=[siss]
# src=[care], target=[car], predicted=[saee]
# src=[won], target=[one], predicted=[won]
# src=[care], target=[car], predicted=[saee]
# src=[git], target=[get], predicted=[tttt]
# src=[plase], target=[place], predicted=[sales]
# src=[wor], target=[were], predicted=[woe]
# src=[brite], target=[bright], predicted=[trrte]
# src=[trane], target=[train], predicted=[tiiee]
# src=[fivret], target=[favorite], predicted=[trrtte]
# src=[anamol], target=[Animal], predicted=[allll]
# src=[thay], target=[they], predicted=[they]
# src=[cut], target=[cute], predicted=[soot]
# src=[colest], target=[coolest], predicted=[coooos]
# src=[stending], target=[standing], predicted=[tiiiiinn]
# src=[be case], target=[because], predicted=[sacccee]
# src=[ther], target=[their], predicted=[thrr]
# src=[hors], target=[horse], predicted=[saee]
# src=[neks], target=[next], predicted=[siie]
# src=[becas], target=[because], predicted=[saacss]
# src=[thay], target=[they], predicted=[they]
# src=[rases], target=[races], predicted=[sssss]
# src=[shep], target=[sheep], predicted=[saiee]
# src=[thay], target=[they], predicted=[they]
# src=[folow], target=[follow], predicted=[wolll]
# src=[whay], target=[why], predicted=[hhy]
# src=[hangre], target=[hungry], predicted=[riinn]
# src=[one], target=[once], predicted=[wonn]
# src=[gust], target=[just], predicted=[ssss]
# src=[lest], target=[last], predicted=[soss]
# src=[nighte], target=[night], predicted=[ttttt]
# src=[snekt], target=[sneaked], predicted=[siiit]
# src=[thay], target=[they], predicted=[they]
# src=[wer], target=[were], predicted=[wee]
# src=[gay], target=[guy], predicted=[hey]
# src=[thay], target=[they], predicted=[they]
# src=[anolying], target=[annoying], predicted=[llllnn]
# src=[trid], target=[tried], predicted=[srred]
# src=[mak], target=[make], predicted=[mmy]
# src=[wokt], target=[walked], predicted=[wooo]
# src=[thousen], target=[thousand], predicted=[coooot]
# src=[miyols], target=[miles], predicted=[salme]
# src=[smald], target=[smelled], predicted=[samme]
# src=[stor], target=[store], predicted=[stttt]
# src=[shep], target=[sheep], predicted=[saiee]
# src=[befor], target=[before], predicted=[foooee]
# src=[gras], target=[grass], predicted=[saee]
# src=[som], target=[some], predicted=[smme]
# src=[gras], target=[grass], predicted=[saee]
# src=[so], target=[saw], predicted=[so]
# src=[caming], target=[coming], predicted=[siiiin]
# src=[so], target=[saw], predicted=[so]
# src=[rand], target=[ran], predicted=[winn]
# src=[rand], target=[ran], predicted=[winn]
# src=[miyols], target=[miles], predicted=[salme]
# src=[evry], target=[every], predicted=[taeyy]
# src=[rand], target=[ran], predicted=[winn]
# src=[tok], target=[took], predicted=[woo]
# src=[tonit], target=[tonight], predicted=[tiitt]
# src=[mor], target=[more], predicted=[soe]
# src=[racke], target=[rake], predicted=[caaky]
# src=[kice], target=[kick], predicted=[saee]
# src=[muole], target=[mule], predicted=[colll]
# src=[flut], target=[flute], predicted=[oooo]
# src=[fead], target=[feed], predicted=[saed]
# src=[moch], target=[much], predicted=[sooo]
# src=[lisan], target=[listen], predicted=[siiie]
# src=[swiming], target=[swimming], predicted=[siiiiii]
# src=[oreng], target=[orange], predicted=[fiinn]
# src=[moch], target=[much], predicted=[sooo]
# src=[to], target=[too], predicted=[to]
# src=[cheescake], target=[cheesecake], predicted=[cccccaa]
# src=[sqweeking], target=[squeaking], predicted=[ciiiiiin]
# src=[shep], target=[sheep], predicted=[saiee]
# src=[and], target=[end], predicted=[wind]
# src=[thay], target=[they], predicted=[they]
# src=[becas], target=[because], predicted=[saacss]
# src=[or], target=[are], predicted=[woe]
# src=[butyfol], target=[beautiful], predicted=[cooooll]
# src=[summor], target=[summer], predicted=[smmmmmm]
# src=[becas], target=[because], predicted=[saacss]
# src=[cud], target=[could], predicted=[saed]
# src=[becas], target=[because], predicted=[saacss]
# src=[wen], target=[when], predicted=[wnn]
# src=[rely], target=[really], predicted=[aally]
# src=[rely], target=[really], predicted=[aally]
# src=[rely], target=[really], predicted=[aally]
# src=[rely], target=[really], predicted=[aally]
# src=[sof], target=[soft], predicted=[sooe]
# src=[furgot], target=[forgot], predicted=[totttt]
# src=[chokelet], target=[chocolate], predicted=[cooolle]
# src=[mirr], target=[mirror], predicted=[srre]
# src=[win], target=[when], predicted=[wnn]
# src=[slep], target=[sleep], predicted=[sllle]
# src=[sed], target=[said], predicted=[saed]
# src=[fregot], target=[forgot], predicted=[ttttt]
# src=[many], target=[money], predicted=[wey]
# src=[bak], target=[back], predicted=[woll]
# src=[loking], target=[looking], predicted=[oolinn]
# src=[cut], target=[cute], predicted=[soot]
# src=[nam], target=[name], predicted=[see]
# src=[namd], target=[named], predicted=[saed]
# src=[thay], target=[they], predicted=[they]
# src=[wokt], target=[walked], predicted=[wooo]
# src=[than], target=[then], predicted=[thhh]
# src=[thar], target=[there], predicted=[thhe]
# src=[mean], target=[man], predicted=[wae]
# src=[werd], target=[weird], predicted=[wrrd]
# src=[wok], target=[walk], predicted=[wol]
# src=[fas], target=[fast], predicted=[ssss]
# src=[fouling], target=[following], predicted=[llliin]
# src=[sed], target=[said], predicted=[saed]
# src=[way], target=[why], predicted=[hy]
# src=[foling], target=[following], predicted=[lliinn]
# src=[becas], target=[because], predicted=[saacss]
# src=[now], target=[Know], predicted=[won]
# src=[thar], target=[there], predicted=[thhe]
# src=[elefant], target=[elephant], predicted=[llliin]
# src=[woking], target=[walking], predicted=[ooinnn]
# src=[dech], target=[beach], predicted=[taae]
# src=[sad], target=[said], predicted=[saed]
# src=[whater], target=[water], predicted=[thrre]
# src=[agen], target=[again], predicted=[winn]
# src=[sad], target=[said], predicted=[saed]
# src=[mather], target=[mother], predicted=[thhhe]
# src=[bady], target=[baby], predicted=[saeyy]
# src=[whant], target=[went], predicted=[hhnn]
# src=[deach], target=[beach], predicted=[caaae]
# src=[raning], target=[running], predicted=[iinnnn]
# src=[slipt], target=[slipped], predicted=[siiiie]
# src=[wod], target=[would], predicted=[wol]
# src=[flay], target=[fly], predicted=[mally]
# src=[crasy], target=[crazy], predicted=[seeey]
# src=[frend], target=[friend], predicted=[riine]
# src=[unecorn], target=[unicorn], predicted=[fooiin]
# src=[dackpack], target=[backpack], predicted=[cclllll]
# src=[unecorn], target=[unicorn], predicted=[fooiin]
# src=[whith], target=[with], predicted=[thhh]
# src=[alectrek], target=[electric], predicted=[cccccae]
# src=[suter], target=[scooter], predicted=[stttte]
# src=[ups stars], target=[upstairs], predicted=[sssiisss]
# src=[peanot doter], target=[peanut butter], predicted=[crrtttrrre]
# src=[flowt], target=[float], predicted=[ooole]
# src=[logh], target=[laugh], predicted=[oooo]
# src=[flote], target=[float], predicted=[ooole]
# src=[smoak], target=[smoke], predicted=[smmmm]
# src=[squrule], target=[squirrel], predicted=[sccciie]
# src=[rian], target=[rain], predicted=[winn]
# src=[giroff], target=[giraffe], predicted=[fiiiee]
# src=[huging], target=[hugging], predicted=[fiinng]
# src=[eliffent], target=[elephant], predicted=[fiiiiin]
# src=[stiripes], target=[stripes], predicted=[seiiiiss]
# src=[animalls], target=[animals], predicted=[lllliies]
# src=[frenid], target=[friend], predicted=[riinn]
# src=[fite], target=[fight], predicted=[titt]
# src=[fiteing], target=[fighting], predicted=[tiiinn]
# src=[casis], target=[cases], predicted=[ssssss]
# src=[stared], target=[started], predicted=[sarree]
# src=[fiered], target=[fired], predicted=[rrredd]
# src=[fand], target=[found], predicted=[finn]
# src=[fand], target=[found], predicted=[finn]
# src=[fierst], target=[first], predicted=[siitt]
# src=[fite], target=[fight], predicted=[titt]
# src=[oners], target=[owners], predicted=[siiess]
# src=[evething], target=[everything], predicted=[ttttiing]
# src=[tietts], target=[tickets], predicted=[stttt]
# src=[agenst], target=[against], predicted=[siiitt]
# src=[beagen], target=[begin], predicted=[aaiinn]
# src=[bot], target=[bought], predicted=[toot]
# src=[seads], target=[seeds], predicted=[ssesse]
# src=[grand], target=[ground], predicted=[riine]
# src=[gluve], target=[glove], predicted=[lllle]
# src=[rete], target=[ready], predicted=[ttee]
# src=[cot], target=[caught], predicted=[toot]
# src=[faerl], target=[foul], predicted=[aalle]
# src=[deth], target=[death], predicted=[tttt]
# src=[vale], target=[valley], predicted=[alll]
# src=[steem], target=[steam], predicted=[seaee]
# src=[haer], target=[hair], predicted=[thee]
# src=[crard], target=[crowd], predicted=[srrre]
# src=[waerled], target=[wild], predicted=[aallee]
# src=[cleank], target=[clink], predicted=[lllll]
# src=[teem], target=[team], predicted=[seee]
# src=[hiting], target=[hitting], predicted=[tiinng]
# src=[pooshing], target=[pushing], predicted=[cooooii]
# src=[choowing], target=[chewing], predicted=[coooog]
# src=[caching], target=[catching], predicted=[coooii]
# src=[sode], target=[soda], predicted=[saae]
# src=[skiterles], target=[skittles], predicted=[seecceee]
# src=[flawer], target=[flower], predicted=[alllee]
# src=[seads], target=[seeds], predicted=[ssesse]
# src=[peases], target=[pieces], predicted=[sssssss]
# src=[cleank], target=[clink], predicted=[lllll]
# src=[stadeum], target=[stadium], predicted=[saaaame]
# src=[teem], target=[team], predicted=[seee]
# src=[werming], target=[warming], predicted=[aiiinn]
# src=[faerl], target=[foul], predicted=[aalle]
# src=[gloff], target=[glove], predicted=[folll]
# src=[spiting], target=[spitting], predicted=[siiiiin]
# src=[flawer], target=[flower], predicted=[alllee]
# src=[seads], target=[seeds], predicted=[ssesse]
# src=[grand], target=[ground], predicted=[riine]
# src=[geting], target=[getting], predicted=[tiiing]
# src=[redy], target=[ready], predicted=[eeey]
# src=[cleank], target=[clink], predicted=[lllll]
# src=[sors], target=[soars], predicted=[sssss]
# src=[stadeum], target=[stadium], predicted=[saaaame]
# src=[bateroosh], target=[Baton Rouge], predicted=[cccccttt]
# src=[ticettes], target=[tickets], predicted=[sttttss]
# src=[agenst], target=[against], predicted=[siiitt]
# src=[glave], target=[glove], predicted=[allle]
# src=[rete], target=[ready], predicted=[ttee]
# src=[ferst], target=[first], predicted=[stttt]
# src=[ining], target=[inning], predicted=[iinnn]
# src=[stike], target=[strike], predicted=[saiie]
# src=[stike], target=[strike], predicted=[saiie]
# src=[cleank], target=[clink], predicted=[lllll]
# src=[sors], target=[soars], predicted=[sssss]
# src=[thow], target=[through], predicted=[thhh]
# src=[therd], target=[third], predicted=[trrre]
# src=[thow], target=[through], predicted=[thhh]
# src=[ining], target=[inning], predicted=[iinnn]
# src=[thaer], target=[their], predicted=[thhre]
# src=[bater ], target=[batter], predicted=[ttttee]
# src=[eseay], target=[easy], predicted=[seey]
# src=[pich], target=[pitch], predicted=[toot]
# src=[pich], target=[pitch], predicted=[toot]
# src=[thow], target=[through], predicted=[thhh]
# src=[ferist], target=[first], predicted=[siitt]
# src=[thay], target=[they], predicted=[they]
# src=[thay], target=[they], predicted=[they]
# src=[your], target=[you're], predicted=[wooe]
# src=[stick], target=[strike], predicted=[stiie]
# src=[stick], target=[strike], predicted=[stiie]
# src=[stick], target=[strike], predicted=[stiie]
# src=[ining], target=[inning], predicted=[iinnn]
# src=[ining], target=[inning], predicted=[iinnn]
# src=[chapinship], target=[championship], predicted=[ceepiiiiin]
# src=[ferist], target=[first], predicted=[siitt]
# src=[anether], target=[another], predicted=[trrrrt]
# src=[loded], target=[loaded], predicted=[wolld]
# src=[feard], target=[field], predicted=[rrred]
# src=[crad], target=[crowd], predicted=[saadd]
# src=[waerd], target=[wild], predicted=[waeee]
# src=[ining], target=[inning], predicted=[iinnn]
# src=[mose], target=[moose], predicted=[ssss]
# src=[jerny], target=[journey], predicted=[trree]
# src=[soot], target=[shoot], predicted=[sooo]
# src=[sow], target=[saw], predicted=[soo]
# src=[hapend], target=[happened], predicted=[fainee]
# src=[aproprit], target=[appropriate], predicted=[rrrrrrree]
# src=[acurit], target=[accurate], predicted=[ccccte]
# src=[inplisit], target=[implicit], predicted=[siiiiii]
# src=[explist], target=[explicit], predicted=[slliiis]
# src=[qustions], target=[questions], predicted=[ssiiiiis]
# src=[may], target=[my], predicted=[my]
# src=[sester], target=[sister], predicted=[stttee]
# src=[may], target=[my], predicted=[my]
# src=[brater], target=[brother], predicted=[trrrrr]
# src=[may], target=[my], predicted=[my]
# src=[cosen], target=[cousin], predicted=[sooos]
# src=[frenz], target=[friends], predicted=[riinn]
# src=[samtams], target=[sometimes], predicted=[ssssmmms]
# src=[vesets], target=[visits], predicted=[ssssss]
# src=[mi ], target=[me], predicted=[me]
# src=[bicas], target=[because], predicted=[sacsss]
# src=[may], target=[my], predicted=[my]
# src=[shi], target=[she], predicted=[see]
# src=[riad], target=[ride], predicted=[saed]
# src=[bikse], target=[bikes], predicted=[saiie]
# src=[brot], target=[brought], predicted=[tottt]
# src=[bicas], target=[because], predicted=[sacsss]
# src=[thay], target=[they], predicted=[they]
# src=[weth], target=[with], predicted=[thhh]
# src=[evirthing], target=[everything], predicted=[trrttiing]
# src=[abat], target=[about], predicted=[tooe]
# src=[may], target=[my], predicted=[my]
# src=[famelli], target=[family], predicted=[llllll]
# src=[frends], target=[friends], predicted=[riieee]
# src=[becus], target=[because], predicted=[saccss]
# src=[thay], target=[they], predicted=[they]
# src=[may], target=[my], predicted=[my]
# src=[yus], target=[uses], predicted=[see]
# src=[grol], target=[girl], predicted=[woll]
# src=[gofrend], target=[girlfriend], predicted=[frrrree]
# src=[wheth], target=[with], predicted=[thhh]
# src=[may], target=[my], predicted=[my]
# src=[bother], target=[brother], predicted=[tttttt]
# src=[gams], target=[games], predicted=[sssss]
# src=[tha], target=[the], predicted=[thh]
# src=[cumpiter], target=[computer], predicted=[ccccccee]
# src=[wheth], target=[with], predicted=[thhh]
# src=[may], target=[my], predicted=[my]
# src=[famoly], target=[family], predicted=[mlllly]
# src=[grol], target=[girl], predicted=[woll]
# src=[nam], target=[name], predicted=[see]
# src=[popis], target=[puppies], predicted=[siioss]
# src=[weth], target=[with], predicted=[thhh]
# src=[tha], target=[the], predicted=[thh]
# src=[scrind], target=[screamed], predicted=[siiiie]
# src=[thro], target=[throw], predicted=[thhh]
# src=[wen], target=[when], predicted=[wnn]
# src=[bicos], target=[becasue], predicted=[soouss]
# src=[gut], target=[got], predicted=[tott]
# src=[mi ], target=[me], predicted=[me]
# src=[rit], target=[write], predicted=[tttt]
# src=[wheth], target=[with], predicted=[thhh]
# src=[may], target=[my], predicted=[my]
# src=[dunot], target=[do not], predicted=[fooot]
# src=[lac], target=[like], predicted=[soll]
# src=[beter], target=[better], predicted=[tttte]
# src=[stoveris], target=[strawberries], predicted=[scccccees]
# src=[deleshes], target=[delicious], predicted=[slcciiiss]
# src=[focx], target=[fox], predicted=[wooo]
# src=[tha], target=[the], predicted=[thh]
# src=[comen], target=[come in], predicted=[soooo]
# src=[may], target=[my], predicted=[my]
# src=[lif], target=[life], predicted=[wiie]
# src=[dctor], target=[doctor], predicted=[tootte]
# src=[tha], target=[the], predicted=[thh]
# src=[sed], target=[said], predicted=[saed]
# src=[may], target=[my], predicted=[my]
# src=[tichor], target=[teacher], predicted=[tttthe]
# src=[kindirgartin], target=[kindergarten], predicted=[frrrrrrinn]
# src=[sow], target=[so], predicted=[soo]
# src=[cen], target=[can], predicted=[win]
# src=[techden], target=[teach them], predicted=[tttthh]
# src=[adawt], target=[about], predicted=[waoee]
# src=[watir], target=[water], predicted=[trree]
# src=[coud], target=[could], predicted=[soou]
# src=[supor], target=[super], predicted=[sooooe]
# src=[hirow], target=[hero], predicted=[whhe]
# src=[sow], target=[so], predicted=[soo]
# src=[somwan], target=[someone], predicted=[soooin]
# src=[nids], target=[needs], predicted=[siiss]
# src=[cen], target=[can], predicted=[win]
# src=[hir], target=[her], predicted=[thee]
# src=[war], target=[world], predicted=[wee]
# src=[cach], target=[catch], predicted=[sooo]
# src=[en], target=[on], predicted=[win]
# src=[fiyor], target=[fire], predicted=[waoee]
# src=[favurite], target=[favorite], predicted=[ceccrree]
# src=[fer], target=[fair], predicted=[trre]
# src=[sow], target=[so], predicted=[soo]
# src=[cen], target=[can], predicted=[win]
# src=[gowen], target=[go on], predicted=[woonn]
# src=[rids], target=[rides], predicted=[saeee]
# src=[win], target=[when], predicted=[wnn]
# src=[stof], target=[stuffed], predicted=[soott]
# src=[anamols], target=[animals], predicted=[lllleee]
# src=[dident], target=[didn't], predicted=[fiiiee]
# src=[gow], target=[go], predicted=[woo]
# src=[rad], target=[ride], predicted=[waed]
# src=[tat], target=[that], predicted=[tttt]
# src=[gow], target=[go], predicted=[woo]
# src=[en], target=[on], predicted=[win]
# src=[tha], target=[the], predicted=[thh]
# src=[rad], target=[ride], predicted=[waed]
# src=[gow], target=[go], predicted=[woo]
# src=[si], target=[see], predicted=[sse]
# src=[som], target=[some], predicted=[smme]
# src=[campling], target=[camping], predicted=[llliiin]
# src=[sow], target=[so], predicted=[soo]
# src=[donis], target=[bunnies], predicted=[fiiies]
# src=[cip], target=[keep], predicted=[siie]
# src=[won], target=[one], predicted=[won]
# src=[mavi], target=[maybe], predicted=[saee]
# src=[sweap], target=[sweep], predicted=[saaee]
# src=[chees], target=[cheese], predicted=[saaee]
# src=[teri], target=[tree], predicted=[trre]
# src=[beal], target=[bell], predicted=[walll]
# src=[wheal], target=[wheel], predicted=[wall]
# src=[slead], target=[sled], predicted=[salld]
# src=[sleed], target=[sled], predicted=[salld]
# src=[fleep], target=[flip], predicted=[lllle]
# src=[sweat], target=[sweet], predicted=[saaee]
# src=[breat], target=[bright], predicted=[tttte]
# src=[hed], target=[head], predicted=[weed]
# src=[bred], target=[bread], predicted=[srrdd]
# src=[spel], target=[spill], predicted=[silll]
# src=[sek], target=[sick], predicted=[sae]
# src=[slied], target=[slide], predicted=[siild]
# src=[tiy], target=[tie], predicted=[tey]
# src=[wy], target=[why], predicted=[yy]
# src=[grem], target=[dream], predicted=[saee]
# src=[strit], target=[street], predicted=[stttt]
# src=[thay], target=[they], predicted=[they]
# src=[itz], target=[its], predicted=[seee]
# src=[may], target=[my], predicted=[my]
# src=[therr], target=[their], predicted=[trrrr]
# src=[day], target=[they], predicted=[eeyy]
# src=[chanch], target=[change], predicted=[thhhh]
# src=[tha], target=[the], predicted=[thh]
# src=[bel], target=[bell], predicted=[wall]
# src=[oridi], target=[already], predicted=[aaree]
# src=[es], target=[it's], predicted=[sss]
# src=[tam], target=[time], predicted=[see]
# src=[gou], target=[go], predicted=[woo]
# src=[clas], target=[class], predicted=[saess]
# src=[sow], target=[so], predicted=[soo]
# src=[prepol], target=[purple], predicted=[flllll]
# src=[leps], target=[lips], predicted=[saees]
# src=[hav], target=[have], predicted=[woe]
# src=[perpol], target=[purple], predicted=[flllll]
# src=[ilashes], target=[eyelashes], predicted=[seccisss]
# src=[sow], target=[so], predicted=[soo]
# src=[costum], target=[costume], predicted=[ssccss]
# src=[may], target=[my], predicted=[my]
# src=[costum], target=[costume], predicted=[ssccss]
# src=[ive], target=[Ivy], predicted=[siee]
# src=[desendens], target=[descendants], predicted=[siiiiiiii]
# src=[gevs], target=[gives], predicted=[siiss]
# src=[som], target=[some], predicted=[smme]
# src=[gevs], target=[gives], predicted=[siiss]
# src=[mi ], target=[me], predicted=[me]
# src=[lolipop], target=[lollipop], predicted=[llllll]
# src=[thes], target=[this], predicted=[seee]
# src=[mad], target=[made], predicted=[see]
# src=[mi ], target=[me], predicted=[me]
# src=[smayol], target=[smile], predicted=[smmmm]
# src=[ticher], target=[teacher], predicted=[ttttre]
# src=[drot], target=[brought], predicted=[torte]
# src=[som], target=[some], predicted=[smme]
# src=[pitzza], target=[pizza], predicted=[seee]
# src=[tha], target=[the], predicted=[thh]
# src=[rum], target=[room], predicted=[saee]
# src=[smel], target=[smell], predicted=[smml]
# src=[dileshes], target=[delicious], predicted=[slciiiiss]
# src=[mad], target=[made], predicted=[see]
# src=[mi ], target=[me], predicted=[me]
# src=[lien], target=[lion], predicted=[winn]
# src=[cing], target=[king], predicted=[iiin]
# src=[sem], target=[same], predicted=[seee]
# src=[tim], target=[time], predicted=[seee]
# src=[hapy], target=[happy], predicted=[haeyy]
# src=[oder], target=[other], predicted=[waree]
# src=[clasrums], target=[classrooms], predicted=[sccccccsss]
# src=[ther], target=[there], predicted=[thrr]
# src=[wer], target=[were], predicted=[wee]
# src=[weth], target=[with], predicted=[thhh]
# src=[costum], target=[costume], predicted=[ssccss]
# src=[mi ], target=[me], predicted=[me]
# src=[may], target=[my], predicted=[my]
# src=[frins], target=[friends], predicted=[siiis]
# src=[fil], target=[feel], predicted=[wlll]
# src=[gou], target=[go], predicted=[woo]
# src=[tha], target=[the], predicted=[thh]
# src=[hows], target=[house], predicted=[sooe]
# src=[sow], target=[so], predicted=[soo]
# src=[gevs], target=[gives], predicted=[siiss]
# src=[mi ], target=[me], predicted=[me]
# src=[hom], target=[home], predicted=[soe]
# src=[trecotriding], target=[trick-or-treating], predicted=[ceetttttttttiin]
# src=[weth], target=[with], predicted=[thhh]
# src=[may], target=[my], predicted=[my]
# src=[frins], target=[friends], predicted=[siiis]
# src=[may], target=[my], predicted=[my]
# src=[famoly], target=[family], predicted=[mlllly]
# src=[hog], target=[hug], predicted=[woo]
# src=[tit], target=[tight], predicted=[tttt]
# src=[schoal], target=[school], predicted=[cooool]
# src=[cin], target=[can], predicted=[winn]
# src=[gut], target=[got], predicted=[tott]
# src=[frind], target=[friend], predicted=[fiinn]
# src=[clamed], target=[climbed], predicted=[salmme]
# src=[frind], target=[friend], predicted=[fiinn]
# src=[codd], target=[could], predicted=[soodd]
# src=[frind], target=[friend], predicted=[fiinn]
# src=[skard], target=[scared], predicted=[saadd]
# src=[clamed], target=[climbed], predicted=[salmme]
# src=[a lout], target=[a lot], predicted=[woole]
# src=[a lout], target=[a lot], predicted=[woole]
# src=[haded], target=[had], predicted=[saadd]
# src=[whoud], target=[would], predicted=[wooee]
# src=[hire], target=[hair], predicted=[tere]
# src=[hire], target=[hair], predicted=[tere]
# src=[how], target=[who], predicted=[wh]
# src=[dose], target=[does], predicted=[saee]
# src=[dume], target=[dumb], predicted=[samm]
# src=[stell], target=[still], predicted=[salll]
# src=[anser], target=[answer], predicted=[siiie]
# src=[quasion], target=[question], predicted=[siiiiii]
# src=[compoused], target=[composed], predicted=[sccccoes]
# src=[riag], target=[ring], predicted=[tiie]
# src=[therecer], target=[teacher], predicted=[trrrrrrr]
# src=[feger], target=[figure], predicted=[trrre]
# src=[ther], target=[there], predicted=[thrr]
# src=[whoud], target=[would], predicted=[wooee]
# src=[figer], target=[figure], predicted=[tiiie]
# src=[whore], target=[wrote], predicted=[whhee]
# src=[faviort], target=[favorite], predicted=[foootee]
# src=[rictengal], target=[rectangle], predicted=[trtttii]
# src=[choclat], target=[chocolate], predicted=[cooooo]
# src=[scaches], target=[scratches], predicted=[scccccss]
# src=[traped], target=[trapped], predicted=[rrrree]
# src=[awsome], target=[awesome], predicted=[sammms]
# src=[eveything], target=[everything], predicted=[aaiiiinn]
# src=[relly], target=[really], predicted=[alllly]
# src=[pupkin], target=[pumpkin], predicted=[fiiiin]
# src=[hous], target=[house], predicted=[soos]
# src=[hous], target=[house], predicted=[soos]
# src=[halewen], target=[halloween], predicted=[alllne]
# src=[halewen], target=[halloween], predicted=[alllne]
# src=[frend], target=[friend], predicted=[riine]
# src=[brothe], target=[brother], predicted=[tttttt]
# src=[hous], target=[house], predicted=[soos]
# src=[girel], target=[girl], predicted=[aiiee]
# src=[siting], target=[sitting], predicted=[siiiig]
# src=[custome], target=[costume], predicted=[sccccse]
# src=[frends], target=[friends], predicted=[riieee]
# src=[custome], target=[costume], predicted=[sccccse]
# src=[repe], target=[reaper], predicted=[aaee]
# src=[wen], target=[when], predicted=[wnn]
# src=[yer], target=[year], predicted=[wee]
# src=[hallewen], target=[halloween], predicted=[lllllee]
# src=[plastik], target=[plastic], predicted=[sliiii]
# src=[frend], target=[friend], predicted=[riine]
# src=[Halleween], target=[halloween], predicted=[lllllee]
# src=[coms], target=[comes], predicted=[ssssss]
# src=[hous], target=[house], predicted=[soos]
# src=[ded], target=[dead], predicted=[sadd]
# src=[blod], target=[blood], predicted=[wolll]
# src=[wen], target=[when], predicted=[wnn]
# src=[axed], target=[asked], predicted=[saed]
# src=[cood], target=[could], predicted=[wool]
# src=[yoos], target=[use], predicted=[sooe]
# src=[sed], target=[said], predicted=[saed]
# src=[brock], target=[broke], predicted=[coook]
# src=[here], target=[her], predicted=[tere]
# src=[sed], target=[said], predicted=[saed]
# src=[watever], target=[whatever], predicted=[rrrrree]
# src=[riped], target=[ripped], predicted=[fiidd]
# src=[hed], target=[head], predicted=[weed]
# src=[wat], target=[what], predicted=[the]
# src=[wood], target=[would], predicted=[wool]
# src=[thot], target=[thought], predicted=[thtt]
# src=[ges], target=[guess], predicted=[ssss]
# src=[mised], target=[missed], predicted=[saeee]
# src=[spieck], target=[spike], predicted=[siiiim]
# src=[spieck], target=[spike], predicted=[siiiim]
# src=[pople], target=[people], predicted=[lllll]
# src=[planit], target=[planet], predicted=[fiiinn]
# src=[frice], target=[fries], predicted=[saree]
# src=[sos], target=[sauce], predicted=[ssss]
# src=[thay], target=[they], predicted=[they]
# src=[wofol], target=[waffle], predicted=[wolll]
# src=[solt], target=[salt], predicted=[soooe]
# src=[difrint], target=[different], predicted=[fiiiinn]
# src=[culers], target=[colors], predicted=[sccccss]
# src=[poot], target=[put], predicted=[oooo]
# src=[marbols], target=[marble], predicted=[callee]
# src=[raisan], target=[raisin], predicted=[siiii]
# src=[insid], target=[inside], predicted=[siiid]
# src=[tast], target=[taste], predicted=[sttt]
# src=[lemen], target=[lemon], predicted=[aiiie]
# src=[ech], target=[each], predicted=[thh]
# src=[caler], target=[color], predicted=[calle]
# src=[difrent], target=[different], predicted=[friiinn]
# src=[lik], target=[like], predicted=[wlll]
# src=[frirends], target=[friends], predicted=[rriiee]
# src=[wont], target=[want], predicted=[wonn]
# src=[ice-crem], target=[ice-cream], predicted=[ccccccaa]
# src=[frends], target=[friends], predicted=[riieee]
# src=[exept], target=[except], predicted=[fiiee]
# src=[meen], target=[mean], predicted=[win]
# src=[wen], target=[when], predicted=[wnn]
# src=[ice crem], target=[ice-cream], predicted=[ccccccmm]
# src=[hed], target=[head], predicted=[weed]
# src=[wen], target=[when], predicted=[wnn]
# src=[ice crem], target=[ice-cream], predicted=[ccccccmm]
# src=[sliped], target=[slipped], predicted=[siiied]
# src=[fel], target=[fell], predicted=[wlll]
# src=[grabed], target=[grabbed], predicted=[rrrree]
# src=[fel], target=[fell], predicted=[wlll]
# src=[sed], target=[said], predicted=[saed]
# src=[tipet], target=[tipped], predicted=[ttttt]
# src=[landid], target=[landed], predicted=[fiined]
# src=[hikeing], target=[hiking], predicted=[aiinnn]
# src=[trieing], target=[trying], predicted=[tiiinn]
# src=[relly], target=[really], predicted=[alllly]
# src=[sleded], target=[sled], predicted=[seiddd]
# src=[litel], target=[little], predicted=[allll]
# src=[intell], target=[until], predicted=[filll]
# src=[minits], target=[minutes], predicted=[siiiss]
# src=[onece], target=[once], predicted=[wooee]
# src=[thir], target=[there], predicted=[ttrt]
# src=[crazzy], target=[crazy], predicted=[meayyy]
# src=[waned], target=[wanted], predicted=[winne]
# src=[climed], target=[climbed], predicted=[slllme]
# src=[peise], target=[piece], predicted=[siies]
# src=[werd], target=[weird], predicted=[wrrd]
# src=[ther], target=[there], predicted=[thrr]
# src=[choaclet], target=[chocolate], predicted=[coooooe]
# src=[taseted], target=[tasted], predicted=[statee]
# src=[spiting], target=[spitting], predicted=[siiiiin]
# src=[puncht], target=[punched], predicted=[totttt]
# src=[boke], target=[broke], predicted=[wool]
# src=[mounth], target=[month], predicted=[oooot]
# src=[evrey], target=[every], predicted=[aaayy]
# src=[nexst], target=[next], predicted=[siiss]
# src=[smel], target=[smell], predicted=[smml]
# src=[confidind], target=[confident], predicted=[fiiiiiie]
# src=[furtionet], target=[fortunate], predicted=[trtttttt]
# src=[pooring], target=[pouring], predicted=[fooiin]
# src=[anywear], target=[anywhere], predicted=[aaaeee]
# src=[univeres], target=[universe], predicted=[siiiiies]
# src=[pickture], target=[picture], predicted=[cccctre]
# src=[neighboors], target=[neighbors], predicted=[rrrrrree]
# src=[exsited], target=[excited], predicted=[siiiie]
# src=[vacashin], target=[vacation], predicted=[ccciiii]
# src=[thout], target=[thought], predicted=[toott]
# src=[pictur], target=[picture], predicted=[sttttt]
# src=[whereing], target=[wearing], predicted=[rrinnn]
# src=[lik], target=[like], predicted=[wlll]
# src=[gunn], target=[going to], predicted=[iinnn]
# src=[sower], target=[shower], predicted=[sooue]
# src=[cewed], target=[chewed], predicted=[saaed]
# src=[botel], target=[bottle], predicted=[coool]
# src=[dolfin], target=[dolphin], predicted=[llllnn]
# src=[buteful], target=[beautiful], predicted=[ccocoll]
# src=[asome], target=[awesome], predicted=[sammm]
# src=[weard], target=[weird], predicted=[waeee]
# src=[pich], target=[pitch], predicted=[toot]
# src=[silkey], target=[silky], predicted=[mmmmll]
# src=[frunt], target=[front], predicted=[tiitt]
# src=[choclete], target=[chocolate], predicted=[cooooo]
# src=[quikly], target=[quickly], predicted=[llllll]
# src=[runing], target=[running], predicted=[iiinnn]
# src=[quikly], target=[quickly], predicted=[llllll]
# src=[choclete], target=[chocolate], predicted=[cooooo]
# src=[pich], target=[pitch], predicted=[toot]
# src=[siny], target=[shiny], predicted=[siie]
# src=[check], target=[cheek], predicted=[cooke]
# src=[pare], target=[pair], predicted=[taee]
# src=[climed], target=[climbed], predicted=[slllme]
# src=[climed], target=[climbed], predicted=[slllme]
# src=[luky], target=[lucky], predicted=[mllly]
# src=[fram], target=[from], predicted=[saee]
# src=[check], target=[cheek], predicted=[cooke]
# src=[skream], target=[scream], predicted=[seamm]
# src=[stars], target=[stairs], predicted=[sssss]
# src=[weard], target=[weird], predicted=[waeee]
# src=[blud], target=[blood], predicted=[solld]
# src=[enyware], target=[anywhere], predicted=[aaaeee]
# src=[hospitole], target=[hospital], predicted=[ccccooo]
# src=[trid], target=[tried], predicted=[srred]
# src=[sowed], target=[showed], predicted=[sooue]
# src=[stichs], target=[stitches], predicted=[stttss]
# src=[fiting], target=[fighting], predicted=[tiiing]
# src=[animole], target=[animal], predicted=[llllle]
# src=[Texes], target=[Texas], predicted=[saaee]
# src=[mous], target=[mouse], predicted=[sosss]
# src=[surching], target=[searching], predicted=[tttttiig]
# src=[cathing], target=[catching], predicted=[thttig]
# src=[geteing], target=[getting], predicted=[tiiing]
# src=[tak], target=[take], predicted=[whe]
# src=[wold], target=[would], predicted=[woll]
# src=[resons], target=[reasons], predicted=[siiiss]
# src=[othe], target=[ohter], predicted=[thhh]
# src=[Haloween], target=[Halloween], predicted=[allllee]
# src=[othe], target=[other], predicted=[thhh]
# src=[tortch], target=[torch], predicted=[tttttt]
# src=[sratch], target=[scratch], predicted=[ttttte]
# src=[pla], target=[play], predicted=[wlll]
# src=[hop], target=[hope], predicted=[woo]
# src=[peik], target=[pink], predicted=[aiik]
# src=[frist], target=[first], predicted=[sitts]
# src=[peik], target=[pink], predicted=[aiik]
# src=[dres], target=[dress], predicted=[saeee]
# src=[sh'll], target=[she'll], predicted=[lllll]
# src=[marckr], target=[marker], predicted=[caaaee]
# src=[af], target=[of], predicted=[wee]
# src=[marck], target=[mark], predicted=[saak]
# src=[forst], target=[first], predicted=[stttt]
# src=[bookmrc], target=[bookmark], predicted=[coooooe]
# src=[forst], target=[first], predicted=[stttt]
# src=[peapl], target=[people], predicted=[lllll]
# src=[nite], target=[night], predicted=[titt]
# src=[beech], target=[beach], predicted=[tccte]
# src=[wonderd], target=[wondered], predicted=[frrreee]
# src=[duscoverd], target=[discovered], predicted=[scccccee]
# src=[swiming], target=[swimming], predicted=[siiiiii]
# src=[dallfin], target=[dolphin], predicted=[llllln]
# src=[dallfin], target=[dolphin], predicted=[llllln]
# src=[bekame], target=[became], predicted=[caamme]
# src=[toger], target=[together], predicted=[tottt]
# src=[happly], target=[happily], predicted=[alllll]
# src=[beech], target=[beach], predicted=[tccte]
# src=[wonderd], target=[wondered], predicted=[frrreee]
# src=[funnyest], target=[funniest], predicted=[fiiiitt]
# src=[joks], target=[jokes], predicted=[soous]
# src=[alwase], target=[always], predicted=[alllee]
# src=[vary], target=[very], predicted=[taeyy]
# src=[takeing], target=[taking], predicted=[aiiinn]
# src=[did't], target=[didn't], predicted=[fiiiee]
# src=[woched], target=[watched], predicted=[coooee]
# src=[moove], target=[movie], predicted=[woooe]
# src=[scard], target=[scared], predicted=[saaaee]
# src=[alwase], target=[always], predicted=[alllee]
# src=[Texis], target=[Texas], predicted=[saiss]
# src=[travelling], target=[traveling], predicted=[lllllinn]
# src=[fownd], target=[found], predicted=[wonnn]
# 37 / 900
